# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data  = pd.read_csv("/content/IMDB-Movie-Data.csv")

# %% [markdown]
# 1.
#  Display top 5 row of the dataset **bold text**

# %%
data.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# **2. Check last 5 row of the dataset**

# %%
data.tail(5)
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [markdown]
# **3. Find the shape of the dataset**

# %%
print(f"total rows are {data.shape[0]}")
print(f"total columns are {data.shape[1]}")
# Out:
# total rows are 1000
# total columns are 12

# %% [markdown]
# **4. Getting the information of the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# **5. Check the null value**

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum()/len(data)*100

# %%
per_missing
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# **6. Drop all the missing value**

# %%
data.dropna(axis = 0,inplace = True)

# %%
data.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# **7. Check for duplicate data**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **8. Get overall Statistics About the DataFrame**

# %%
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# **9. Display title of the movie having runtime>=180 minute**

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Runtime (Minutes)']>=180][['Rank', 'Title','Runtime (Minutes)']]
# Out:
#      Rank                    Title  Runtime (Minutes)
# 82     83  The Wolf of Wall Street                180
# 88     89        The Hateful Eight                187
# 311   312           La vie d'Adèle                180

# %% [markdown]
# **10. in which year there was the hight Average voting**

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending = False).head(1)
# Out:
# Year
# 2012    290861.483871
# Name: Votes, dtype: float64

# %% [markdown]
# **11. in which year there was the hight Average Revenue**

# %%
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending = False).head(1)
# Out:
# Year
# 2009    115.742
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# ***12. Find the Average rating for each director ***

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending = False).head()
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
# Name: Rating, dtype: float64

# %% [markdown]
# **13. Display top 10 lengthy movie title and runtime**

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]
# Out:
#                                         Title  Runtime (Minutes)
# 88                          The Hateful Eight                187
# 82                    The Wolf of Wall Street                180
# 311                            La vie d'Adèle                180
# 267                               Cloud Atlas                172
# 430                                  3 Idiots                170
# 36                               Interstellar                169
# 75   Pirates of the Caribbean: At World's End                169
# 271         The Hobbit: An Unexpected Journey                169
# 425       The Curious Case of Benjamin Button                166
# 126           Transformers: Age of Extinction                165

# %% [markdown]
# **14. find the most populer movie title(hight revenue)**

# %%
data.groupby('Title')['Revenue (Millions)'].mean().sort_values(ascending = False).head(1)
# Out:
# Title
# Star Wars: Episode VII - The Force Awakens    936.63
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# **15. Display top 10 highest rated movie title and its director**

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.nlargest(10,'Rating')[['Title','Director']]
# Out:
#                      Title                          Director
# 54         The Dark Knight                 Christopher Nolan
# 80               Inception                 Christopher Nolan
# 36            Interstellar                 Christopher Nolan
# 96           Kimi no na wa                    Makoto Shinkai
# 249       The Intouchables                   Olivier Nakache
# 64            The Prestige                 Christopher Nolan
# 99            The Departed                   Martin Scorsese
# 124  The Dark Knight Rises                 Christopher Nolan
# 133               Whiplash                   Damien Chazelle
# 476    The Lives of Others  Florian Henckel von Donnersmarck

# %% [markdown]
# **15. Find average rating of movies year wise**

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending = False)
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2011    6.945614
# 2012    6.933871
# 2009    6.911111
# 2010    6.894737
# 2013    6.832143
# 2014    6.822581
# 2008    6.708333
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %% [markdown]
# **16. Does Rating Affect the revwnue**

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Revenue (Millions)'].corr(data['Rating'])
# Out:
# 0.21710577610381881

# %%
sns.scatterplot(data = data,x = 'Rating',y = 'Revenue (Millions)')
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>
